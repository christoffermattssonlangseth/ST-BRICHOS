# %%
import warnings
warnings.filterwarnings('ignore')
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "utils")))
from analysis_utils import (
    volcano_plot_br,
    plot_spatial_clusters_per_sample,
    plot_dotplot_by_treatment,
    plot_relative_cluster_composition,
    score_and_plot_modules
)
import scanpy as sc
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

# %%
ad = sc.read_h5ad('../data/ST_BRICHOS_region_subcluster.h5ad')

# %%
plot_spatial_clusters_per_sample(ad, color = 'leiden_0.3', figsize=(20,15))

# %%
compartment_anno = {
    0: 'Caudoputamen',
    1: 'Supragranualar layers',
    2: 'Infragranular layers',
    3: 'Hypothalamus',
    4: 'Corpus callosum',
    5: 'Olfactory areas',
    6: 'Hypothalamus',
    7: 'Meninges',
    8: 'Hippocampal formation',
    9: 'Thalamus',
    10: 'Thalamus',
    11: 'Caudoputamen',
    12: 'Ventricular area'
}

# %%
ad.obs['re_annotation_regions'] = ad.obs['leiden_0.3'].astype(int).map(compartment_anno)

# %%
plot_spatial_clusters_per_sample(ad, color = 're_annotation_regions', figsize=(20,15))
